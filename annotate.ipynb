# %%
import os
import glob

import pandas as pd
import numpy as np

# %%
annotations = pd.read_parquet('/scratch/t.cri.awoodard/indel-filtering/annotations.parquet')
annotations.sort_values('SAMPLE', inplace=True)

# %%
summary = [
    'Func.refGene',
    'Gene.refGene',
    'ExonicFunc.refGene',
    'AAChange.refGene',
    'SAMPLE',
    'pseudo PON',
    'dbsnp',
    'genomes1k'
]

# %%
annotations[
    annotations['AAChange.refGene'].str.contains('NM_001002295') &
    annotations['Gene.refGene'].str.contains('GATA3')
][summary]
# Out:
#        Func.refGene Gene.refGene    ExonicFunc.refGene  \
# 101399       exonic        GATA3  frameshift insertion
# 106000       exonic        GATA3   frameshift deletion
# 101785       exonic        GATA3   frameshift deletion
# 101188       exonic        GATA3  frameshift insertion
# 100697       exonic        GATA3   frameshift deletion
# 101399       exonic        GATA3  frameshift insertion
# 101699       exonic        GATA3  frameshift insertion
# 108454       exonic        GATA3  frameshift insertion
# 109601       exonic        GATA3  frameshift insertion
# 107308       exonic        GATA3  frameshift insertion
# 104129       exonic        GATA3  frameshift insertion
# 107712       exonic        GATA3  frameshift insertion
# 107628       exonic        GATA3   frameshift deletion
# 103398       exonic        GATA3  frameshift insertion
# 107603       exonic        GATA3  frameshift insertion
# 103942       exonic        GATA3  frameshift insertion
# 107873       exonic        GATA3  frameshift insertion
# 107365       exonic        GATA3  frameshift insertion
# 105235       exonic        GATA3  frameshift insertion
# 115620       exonic        GATA3   frameshift deletion
# 92057        exonic        GATA3  frameshift insertion
# 68595        exonic        GATA3  frameshift insertion
#
#                                          AAChange.refGene        SAMPLE  \
# 101399  GATA3:NM_001002295:exon6:c.1224dupG:p.S408fs,G...       L000006
# 106000  GATA3:NM_001002295:exon5:c.985_986del:p.W329fs...       L000083
# 101785  GATA3:NM_001002295:exon6:c.1321_1346del:p.T441...       N010274
# 101188  GATA3:NM_001002295:exon6:c.1332dupT:p.G444fs,G...       N010656
# 100697  GATA3:NM_001002295:exon6:c.1291_1292del:p.F431...       N010721
# 101399  GATA3:NM_001002295:exon6:c.1322dupC:p.T441fs,G...       N010820
# 101699  GATA3:NM_001002295:exon6:c.1305dupC:p.H435fs,G...       N010830
# 108454  GATA3:NM_001002295:exon6:c.1224dupG:p.S408fs,G...       N010891
# 109601  GATA3:NM_001002295:exon6:c.1302dupC:p.H434fs,G...       N010909
# 107308  GATA3:NM_001002295:exon5:c.1003dupG:p.N334fs,G...       N010914
# 104129  GATA3:NM_001002295:exon6:c.1332dupT:p.G444fs,G...       N010929
# 107712  GATA3:NM_001002295:exon5:c.997dupG:p.N332fs,GA...       N010940
# 107628  GATA3:NM_001002295:exon5:c.992_996del:p.R331fs...       N010946
# 103398  GATA3:NM_001002295:exon6:c.1223_1224insT:p.S40...       N010985
# 107603  GATA3:NM_001002295:exon6:c.1305dupC:p.H435fs,G...       N011006
# 103942  GATA3:NM_001002295:exon6:c.1223_1224insA:p.S40...       N011037
# 107873  GATA3:NM_001002295:exon6:c.1223_1224insT:p.S40...       N011047
# 107365  GATA3:NM_001002295:exon6:c.1289_1290insAAAG:p....       N011049
# 105235  GATA3:NM_001002295:exon5:c.1003dupG:p.N334fs,G...       N011070
# 115620  GATA3:NM_001002295:exon6:c.1201_1202del:p.M401...  TCGA-A2-A25B
# 92057   GATA3:NM_001002295:exon6:c.1224dupG:p.S408fs,G...  TCGA-AN-A0XR
# 68595   GATA3:NM_001002295:exon6:c.1201dupA:p.H400fs,G...  TCGA-E2-A15H
#
#        pseudo PON dbsnp genomes1k
# 101399       pass  pass      pass
# 106000       pass  pass      pass
# 101785       pass  pass      pass
# 101188       pass  pass      pass
# 100697       pass  pass      pass
# 101399       pass  pass      pass
# 101699       pass  pass      pass
# 108454       pass  pass      pass
# 109601       pass  pass      pass
# 107308       pass  pass      pass
# 104129       pass  pass      pass
# 107712       pass  pass      pass
# 107628       pass  pass      pass
# 103398       pass  pass      pass
# 107603       pass  pass      pass
# 103942       pass  pass      pass
# 107873       pass  pass      pass
# 107365       pass  pass      pass
# 105235       pass  pass      pass
# 115620       pass  fail      pass
# 92057        pass  pass      pass
# 68595        pass  pass      pass

# %%
annotations[
    annotations['AAChange.refGene'].str.contains('NM_00054') &
    annotations['Gene.refGene'].str.contains('TP53')
][summary]
# Out:
#        Func.refGene Gene.refGene       ExonicFunc.refGene  \
# 433559       exonic         TP53     frameshift insertion
# 431627       exonic         TP53      frameshift deletion
# 431447       exonic         TP53      frameshift deletion
# 396394       exonic         TP53     frameshift insertion
# 447998       exonic         TP53     frameshift insertion
# 413253       exonic         TP53      frameshift deletion
# 421962       exonic         TP53                 stopgain
# 416376       exonic         TP53     frameshift insertion
# 440987       exonic         TP53                 stopgain
# 464909       exonic         TP53     frameshift insertion
# 453785       exonic         TP53     frameshift insertion
# 463084       exonic         TP53      frameshift deletion
# 448315       exonic         TP53      frameshift deletion
# 432414       exonic         TP53      frameshift deletion
# 438232       exonic         TP53   nonframeshift deletion
# 441550       exonic         TP53      frameshift deletion
# 433473       exonic         TP53  frameshift substitution
# 443005       exonic         TP53     frameshift insertion
# 436255       exonic         TP53   nonframeshift deletion
# 429254       exonic         TP53      frameshift deletion
# 314642       exonic         TP53      frameshift deletion
# 311054       exonic         TP53      frameshift deletion
# 288572       exonic         TP53      frameshift deletion
# 248054       exonic         TP53      frameshift deletion
# 394588       exonic         TP53      frameshift deletion
# 379184       exonic         TP53     frameshift insertion
# 299046       exonic         TP53      frameshift deletion
# 379988       exonic         TP53  frameshift substitution
# 414125       exonic         TP53   nonframeshift deletion
# 397618       exonic         TP53     frameshift insertion
# 357020       exonic         TP53      frameshift deletion
#
#                                          AAChange.refGene        SAMPLE  \
# 433559  TP53:NM_001126115:exon1:c.136dupC:p.H46fs,TP53...       L000006
# 431627  TP53:NM_001126118:exon4:c.259_265del:p.Y87fs,T...       L000017
# 431447  TP53:NM_001126118:exon3:c.133_134del:p.A45fs,T...       N009905
# 396394  TP53:NM_000546:exon4:c.102dupC:p.L35fs,TP53:NM...       N010117
# 447998  TP53:NM_001126115:exon6:c.622_623insGA:p.M208f...       N010755
# 413253  TP53:NM_001126115:exon4:c.470delT:p.L157fs,TP5...       N010828
# 421962  TP53:NM_001126118:exon3:c.204delC:p.Y68X,TP53:...       N010867
# 416376  TP53:NM_001126118:exon3:c.99dupC:p.V34fs,TP53:...       N010868
# 440987  TP53:NM_001126115:exon3:c.285dupT:p.D96_C97del...       N010870
# 464909  TP53:NM_001126115:exon2:c.253dupG:p.V85fs,TP53...       N010917
# 453785  TP53:NM_001126118:exon3:c.206dupG:p.G69fs,TP53...       N010926
# 463084  TP53:NM_001126115:exon2:c.233delA:p.N78fs,TP53...       N010936
# 448315  TP53:NM_001126115:exon3:c.327delC:p.S109fs,TP5...       N010945
# 432414  TP53:NM_001126115:exon1:c.95_98del:p.K32fs,TP5...       N010952
# 438232  TP53:NM_001126115:exon2:c.208_222del:p.70_74de...       N010959
# 441550  TP53:NM_001126115:exon1:c.52_56del:p.T18fs,TP5...       N011002
# 433473  TP53:NM_001126115:exon4:c.472_484TTA,TP53:NM_0...       N011005
# 443005  TP53:NM_001126115:exon1:c.98dupA:p.Q33fs,TP53:...       N011022
# 436255  TP53:NM_001126118:exon3:c.256_258del:p.86_86de...       N011040
# 429254  TP53:NM_001126115:exon2:c.239_240del:p.F80fs,T...       N011082
# 314642  TP53:NM_001126118:exon3:c.206delG:p.G69fs,TP53...  TCGA-A2-A04P
# 311054  TP53:NM_001126115:exon1:c.97_125del:p.Q33fs,TP...  TCGA-A8-A07B
# 288572  TP53:NM_001126115:exon2:c.164_267del:p.G55fs,T...  TCGA-A8-A08L
# 248054  TP53:NM_001126115:exon2:c.235delA:p.T79fs,TP53...  TCGA-AO-A0J6
# 394588  TP53:NM_001126118:exon3:c.248_249del:p.V83fs,T...  TCGA-AR-A1AY
# 379184  TP53:NM_001126118:exon3:c.210_211insTC:p.R71fs...  TCGA-AR-A256
# 299046  TP53:NM_001126115:exon4:c.457_475del:p.E153fs,...  TCGA-BH-A18U
# 379988  TP53:NM_001126118:exon3:c.205_210A,TP53:NM_000...  TCGA-D8-A27H
# 414125  TP53:NM_001126115:exon3:c.368_370del:p.123_124...  TCGA-E2-A1LG
# 397618  TP53:NM_001126118:exon3:c.137dupC:p.P46fs,TP53...  TCGA-E2-A1LK
# 357020  TP53:NM_001126115:exon4:c.478_481del:p.K160fs,...  TCGA-EW-A1PH
#
#        pseudo PON dbsnp genomes1k
# 433559       pass  pass      pass
# 431627       pass  pass      pass
# 431447       pass  pass      pass
# 396394       pass  pass      pass
# 447998       pass  pass      pass
# 413253       pass  pass      pass
# 421962       pass  pass      pass
# 416376       pass  fail      pass
# 440987       pass  pass      pass
# 464909       pass  pass      pass
# 453785       pass  pass      pass
# 463084       pass  pass      pass
# 448315       pass  pass      pass
# 432414       pass  pass      pass
# 438232       pass  pass      pass
# 441550       pass  pass      pass
# 433473       pass  pass      pass
# 443005       pass  pass      pass
# 436255       pass  pass      pass
# 429254       pass  fail      pass
# 314642       pass  pass      pass
# 311054       pass  pass      pass
# 288572       pass  pass      pass
# 248054       pass  pass      pass
# 394588       pass  fail      pass
# 379184       pass  pass      pass
# 299046       pass  pass      pass
# 379988       pass  pass      pass
# 414125       pass  fail      pass
# 397618       pass  pass      pass
# 357020       pass  pass      pass

# %%
annotations[
    annotations['AAChange.refGene'].str.contains('NM_007294') &
    annotations['Gene.refGene'].str.contains('BRCA1')
][summary]
# Out:
#        Func.refGene Gene.refGene   ExonicFunc.refGene  \
# 459058       exonic        BRCA1  frameshift deletion
#
#                                          AAChange.refGene   SAMPLE pseudo PON  \
# 459058  BRCA1:NM_007297:exon13:c.4460_4467del:p.V1487f...  L000077       pass
#
#        dbsnp genomes1k
# 459058  pass      pass

# %%
annotations[
    annotations['AAChange.refGene'].str.contains('NM_000059') &
    annotations['Gene.refGene'].str.contains('BRCA2')
][summary]
# Out:
#        Func.refGene Gene.refGene    ExonicFunc.refGene  \
# 294109       exonic        BRCA2  frameshift insertion
#
#                                          AAChange.refGene   SAMPLE pseudo PON  \
# 294109  BRCA2:NM_000059:exon18:c.8268_8269insGAACTGGT:...  N010755       pass
#
#        dbsnp genomes1k
# 294109  pass      pass
